# %% [markdown]
# <a href="https://colab.research.google.com/github/abhay211/DataDiscoveryHub/blob/main/MarketSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MARKET SEGMENTATION:**
#
# Market segmentation is the process of dividing a broad consumer or business market, normally consisting of existing and potential customers, into sub groups of consumers based on some type of shared characteristics.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans,AgglomerativeClustering,DBSCAN,SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import tree
from sklearn import metrics

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #Data Preprocessing

# %%
df=pd.read_csv('Customer.csv')
df.drop(columns=["CUST_ID"],axis=1,inplace=True)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %% [markdown]
# # Handeling Missing Values

# %%
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %% [markdown]
# # Replacing Missing Values with Mean

# %%
df["MINIMUM_PAYMENTS"] = df["MINIMUM_PAYMENTS"].fillna(df["MINIMUM_PAYMENTS"].mean())
df["CREDIT_LIMIT"] = df["CREDIT_LIMIT"].fillna(df["CREDIT_LIMIT"].mean())

# %% [markdown]
# #Visualization

# %%
plt.figure(figsize=(10,60))
for i in range(0,17):
    plt.subplot(17,1,i+1)
    sns.distplot(df[df.columns[i]],kde_kws={'color':'black','bw': 0.1,'lw':3,'label':'KDE'},hist_kws={'color':'g'})
    plt.title(df.columns[i])
plt.tight_layout()

# %% [markdown]
# #Scaling the Data

# %%
scalar=StandardScaler()
scaled_df = scalar.fit_transform(df)

# %% [markdown]
# #PCA

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(scaled_df)
pca_data = pd.DataFrame(data=principal_components ,columns=["PCA1","PCA2"])
pca_data
# Out:
#           PCA1      PCA2
# 0    -1.682221 -1.076452
# 1    -1.138297  2.506474
# 2     0.969683 -0.383524
# 3    -0.873629  0.043165
# 4    -1.599434 -0.688582
# ...        ...       ...
# 8945 -0.359629 -2.016146
# 8946 -0.564369 -1.639122
# 8947 -0.926204 -1.810786
# 8948 -2.336551 -0.657964
# 8949 -0.556420 -0.400463
#
# [8950 rows x 2 columns]

# %%
plt.scatter(pca_data["PCA1"], pca_data["PCA2"])
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.title("PCA Visualization")
plt.show()

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.27290037 0.20301991]

# %%
print(pca.components_)
# Out:
# [[ 0.10107747  0.12004343  0.41164152  0.34640699  0.33681429 -0.02334332
#    0.32149284  0.2946332   0.27470975 -0.08913896 -0.04865397  0.39069528
#    0.21166295  0.26624906  0.06035129  0.1321123   0.08102049]
#  [ 0.40395691  0.13053713  0.04103774  0.06287178 -0.01853291  0.43924133
#   -0.19078031 -0.01792387 -0.17860088  0.43408259  0.41973373 -0.01939389
#    0.23867815  0.25747633  0.16696961 -0.1900256  -0.00432652]]

# %% [markdown]
# # Elbow Method to find k

# %%
inertia = []
range_val = range(1,15)
for i in range_val:
    kmean = KMeans(n_clusters=i)
    kmean.fit_predict(pd.DataFrame(scaled_df))
    inertia.append(kmean.inertia_)
plt.plot(range_val,inertia,'bx-')
plt.xlabel('Values of K')
plt.ylabel('Inertia')
plt.title('The Elbow Method using Inertia')
plt.show()

# %% [markdown]
# # KMeans

# %%
kmeans=KMeans(4)
kmeans.fit_predict(scaled_df)
pca_df_kmean= pd.concat([pca_data,pd.DataFrame({'cluster':kmeans.labels_})],axis=1)

# %%
plt.figure(figsize=(8,8))
ax=sns.scatterplot(x="PCA1",y="PCA2",hue="cluster",data=pca_df_kmean,palette=['green','red','blue','yellow'])
plt.title("Clustering using K-Means Algorithm")
plt.show()

# %% [markdown]
# #Finding the cluster centers

# %%
cluster_centers = pd.DataFrame(data=kmeans.cluster_centers_,columns=[df.columns])

# %%
cluster_centers = scalar.inverse_transform(cluster_centers)
cluster_centers = pd.DataFrame(data=cluster_centers,columns=[df.columns])
cluster_centers
# Out:
#        BALANCE BALANCE_FREQUENCY    PURCHASES ONEOFF_PURCHASES  \
# 0   894.907458          0.934734  1236.178934       593.974874
# 1  1011.751528          0.789871   269.973466       209.853863
# 2  3551.153761          0.986879  7681.620098      5095.878826
# 3  4602.462714          0.968415   501.896219       320.373681
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0             642.478274   210.570626            0.885165
# 1              60.386625   595.759339            0.170146
# 2            2587.208264   653.638891            0.946418
# 3             181.607404  4520.724309            0.287731
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.297070                         0.711842
# 1                   0.086281                         0.080578
# 2                   0.739031                         0.788060
# 3                   0.138934                         0.185516
#
# ...

# %% [markdown]
# # Creating a cluster column as target for modeling

# %%
cluster_df = pd.concat([df,pd.DataFrame({'Cluster':kmeans.labels_})],axis=1)
cluster_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# ...

# %%
cluster_1_df = cluster_df[cluster_df["Cluster"]==0]
cluster_1_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2     2495.148862           1.000000     773.17            773.17
# 5     1809.828751           1.000000    1333.28              0.00
# 7     1823.652743           1.000000     436.20              0.00
# 10    1293.124939           1.000000     920.12              0.00
# 12    1516.928620           1.000000    3217.99           2500.23
# ...           ...                ...        ...               ...
# 8940   130.838554           1.000000     591.24              0.00
# 8942    40.829749           1.000000     113.28              0.00
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2                       0.00           0.0             1.000000
# ...

# %%
cluster_2_df = cluster_df[cluster_df["Cluster"]==1]
cluster_2_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# 8     1014.926473           1.000000     861.49            661.49
# 9      152.225975           0.545455    1281.60           1281.60
# ...           ...                ...        ...               ...
# 8939   728.352548           1.000000     734.40            734.40
# 8943     5.871712           0.500000      20.90             20.90
# 8944   193.571722           0.833333    1012.73           1012.73
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                       95.4      0.000000             0.166667
# ...

# %%
cluster_3_df = cluster_df[cluster_df["Cluster"]==2]
cluster_3_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 6      627.260806           1.000000    7091.01           6402.63
# 21    6369.531318           1.000000    6359.95           5910.04
# 57    2386.330629           1.000000    5217.62           4789.09
# 84    1935.362486           1.000000    4915.60           4515.34
# 90    9381.255094           1.000000    5100.07           1147.83
# ...           ...                ...        ...               ...
# 8215  4436.557694           1.000000    6005.90           5838.38
# 8541  3326.323283           1.000000    8209.77           2218.28
# 8662   599.909949           1.000000    4947.32           3149.59
# 8689   368.318662           0.909091    8053.95           8053.95
# 8737  2533.618119           0.909091    5633.83           2985.92
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 6                     688.38      0.000000             1.000000
# ...

# %%
cluster_4_df = cluster_df[cluster_df["Cluster"] == 3]
cluster_4_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 1     3202.467416           0.909091       0.00              0.00
# 15    6886.213231           1.000000    1611.70              0.00
# 23    3800.151377           0.818182    4248.35           3454.56
# 24    5368.571219           1.000000       0.00              0.00
# 28    7152.864372           1.000000     387.05            204.55
# ...           ...                ...        ...               ...
# 8857  2330.222764           1.000000    1320.00              0.00
# 8858   812.934042           1.000000      50.00             50.00
# 8869  2171.222526           1.000000     791.18            791.18
# 8915   381.341657           1.000000      78.00              0.00
# 8941  5967.475270           0.833333     214.55              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 1                       0.00   6442.945483             0.000000
# ...

# %% [markdown]
# # Cluster Count Visualization

# %%
sns.countplot(x='Cluster', data=cluster_df)
# Out:
# <Axes: xlabel='Cluster', ylabel='count'>

# %% [markdown]
# # Splitting the data

# %%
X = cluster_df.drop(['Cluster'],axis=1)
y= cluster_df[['Cluster']]
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.3,random_state=3)

# %% [markdown]
# # Decision Tree Classifier

# %%
model= DecisionTreeClassifier(criterion="entropy")
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      1023
#            1       0.95      0.95      0.95      1164
#            2       0.92      0.90      0.91       121
#            3       0.90      0.89      0.89       377
#
#     accuracy                           0.94      2685
#    macro avg       0.93      0.92      0.93      2685
# weighted avg       0.94      0.94      0.94      2685
